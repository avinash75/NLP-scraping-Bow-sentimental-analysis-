# %%
import string
from collections import Counter

import matplotlib.pyplot as plt

# %%
def get_tweets():
    import GetOldTweets3 as got   # library used to scrape data from twitter without any other tools
    tweetCriteria = got.manager.TweetCriteria().setQuerySearch('#corona') \
        .setSince("2020-01-10") \
        .setUntil("2020-01-20") \
        .setMaxTweets(100)
    # Creation of list that contains all tweets
    tweets = got.manager.TweetManager.getTweets(tweetCriteria)
    # Creating list of chosen tweet data
    text_tweets = [[tweet.text] for tweet in tweets]
    return text_tweets

# %%
# reading text file
text = ""
text_tweets = get_tweets()

length = len(text_tweets)

for i in range(0, length):
    text = text_tweets[i][0] + " " + text

# converting to lowercase
lower_case = text.lower()

# Removing punctuations
cleaned_text = lower_case.translate(str.maketrans('', '', string.punctuation))

# splitting text into words
tokenized_words = cleaned_text.split()
tokenized_words
# Out:
# ['india',
#  'delhi',
#  'afternoon',
#  'smog',
#  'sunset',
#  'orange',
#  'sun',
#  'corona',
#  'akshardhamtemple',
#  'akshardham',
#  'httpswwwinstagramcompb7dimxhnlkand50w8mqembbipahjh7aqkf41yi0igshid1d1jw34cj241k',
#  'corona',
#  'render',
#  'formats',
#  'now',
#  'supported',
#  'b3d',
#  'சீனாவில்',
#  'பரவிவரும்',
#  'மர்ம',
#  'வைரஸ்',
#  'இருவர்',
#  'உயிரிழப்பு',
#  'httpssharesa3inxc',
#  'china',
#  'virus',
#  'corona',
#  'neues',
#  'virus',
#  'in',
#  'china',
#  'weitere',
#  'infektionen',
#  'mit',
#  'lungenkrankheit',
#  'httpwwwtagesschaudeauslandchinalungenkrankheit107html',
#  'corona',
#  'la',
#  'festa',
#  'più',
#  'romantica',
#  'dellanno',
#  'sta',
#  'per',
#  'arrivaregrazie',
#  'alla',
#  'pietracentrale',
#  'che',
#  'funge',
#  'da',
#  'proiettore',
#  'è',
#  'possibile',
#  'visualizzare',
#  'la',
#  'parola',
#  'tiamoin',
#  '100',
#  'lingue',
#  'diverse',
#  'linkhttpswwwebayititm164017103263',
#  'anello',
#  'corona',
# ...

# %%
# Print texts
text_tweets
# Out:
# [['#GoPackGo #PackersVs49ers #GBvsSF noooooooo!!! So much for sparkling water...I need a vice for this game #Corona #findyourbeach #Cerveza'],
#  ['@tonyromo in the #CBS booth taking full advantage of his #Corona deal #DrunkAF'],
#  ['Der Schiri ist grad mir Tony Romo auf Corona Island #Schiri #rannfl #rannflsüchtig @ransport @Icke41 #Corona #TonyRomo'],
#  ['(MEMORY LANE/FLASH BACK) "SIGN AT DA BOTTEMLINE" LIVE AT THE VELVET LOUNGE IN LONG ISLAND NY. #BottemLine #BoomBap #VinnyIdol #Bars #BoyzLifeEnt #StayPositive #WeActive #Qthoro #Corona #velvetlounge #hiphopart… https://www.instagram.com/p/B7hNYVhJDDe/?igshid=g765kvcqnle1'],
#  ['Vive la vida como en la Playa llena de Magia, Sueños y Felicidad ! #tutambiendejatuhuella #noche #playa #amigos #cerveza #corona #arena #fiesta en El Rodadero Beach, Santa Marta - Colombia https://www.instagram.com/p/B7hMqsWH6CR/?igshid=1a7k3pgqcitiy'],
# ...

# %%
stop_words = ["i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself",
              "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself",
              "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these",
              "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do",
              "does", "did", "doing", "a", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while",
              "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before",
              "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again",
              "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each",
              "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than",
              "too", "very", "s", "t", "can", "will", "just", "don", "should", "now"]

# Removing stop words from the tokenized words list
final_words = [word for word in tokenized_words if word not in stop_words]
final_words
# Out:
# ['india',
#  'delhi',
#  'afternoon',
#  'smog',
#  'sunset',
#  'orange',
#  'sun',
#  'corona',
#  'akshardhamtemple',
#  'akshardham',
#  'httpswwwinstagramcompb7dimxhnlkand50w8mqembbipahjh7aqkf41yi0igshid1d1jw34cj241k',
#  'corona',
#  'render',
#  'formats',
#  'supported',
#  'b3d',
#  'சீனாவில்',
#  'பரவிவரும்',
#  'மர்ம',
#  'வைரஸ்',
#  'இருவர்',
#  'உயிரிழப்பு',
#  'httpssharesa3inxc',
#  'china',
#  'virus',
#  'corona',
#  'neues',
#  'virus',
#  'china',
#  'weitere',
#  'infektionen',
#  'mit',
#  'lungenkrankheit',
#  'httpwwwtagesschaudeauslandchinalungenkrankheit107html',
#  'corona',
#  'la',
#  'festa',
#  'più',
#  'romantica',
#  'dellanno',
#  'sta',
#  'per',
#  'arrivaregrazie',
#  'alla',
#  'pietracentrale',
#  'che',
#  'funge',
#  'da',
#  'proiettore',
#  'è',
#  'possibile',
#  'visualizzare',
#  'la',
#  'parola',
#  'tiamoin',
#  '100',
#  'lingue',
#  'diverse',
#  'linkhttpswwwebayititm164017103263',
#  'anello',
#  'corona',
#  'sanvalentino',
# ...

# %%
# Get emotions text
emotion_list = []
with open('emotions.txt', 'r') as file:
    for line in file:
        clear_line = line.replace('\n', '').replace(',', '').replace("'", '').strip()
        word, emotion = clear_line.split(':')
        if word in final_words:
            emotion_list.append(emotion)
#updating emotion_list
emotion_list.append('sad')

w = Counter(emotion_list)
print(w,len(emotion_list))
# Out:
# Counter({' happy': 2, ' loved': 1, ' fearful': 1, ' free': 1, ' attached': 1, ' esteemed': 1, 'sad': 1}) 8

# %%
fig, ax1 = plt.subplots()
ax1.bar(w.keys(), w.values())
fig.autofmt_xdate()
plt.savefig('graph.png')
plt.show()

# %%
#count vectorizer for bag of words
from sklearn.feature_extraction.text import CountVectorizer 

from nltk.corpus import stopwords
import pandas as pd

stop_words = stopwords.words('english')


vect1 = CountVectorizer(stop_words=stop_words)
print (vect1)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None,
#                 stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours',
#                             'ourselves', 'you', "you're", "you've", "you'll",
#                             "you'd", 'your', 'yours', 'yourself', 'yourselves',
#                             'he', 'him', 'his', 'himself', 'she', "she's",
#                             'her', 'hers', 'herself', 'it', "it's", 'its',
#                             'itself', ...],
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
vect1.fit_transform(tokenized_words)
print("bag of words :",vect1.get_feature_names())
print("vocab        :",vect1.vocabulary_)
# Out:
# bag of words : ['0900h', '10', '100', '10am3pm', '10half', '113225', '131', '15', '17', '17full', '18662595647', '1900', '198', '19gennaio', '20', '2004', '20062006', '2015', '2019', '2020', '20th', '23', '24th', '25', '2500', '300', '31', '324', '3d', '3dmax', '3dmodelling', '3ds', '3dsmax', '3dvisualization', '4027', '40añosdelpickup', '4140', '428i', '49ers', '4dr', '500', '630pm8pm', '718', '730', '97th', '9ers', '9pm', 'accessori', 'accio', 'aceofbase', 'achievement', 'adorable', 'advantage', 'afc', 'africa', 'afternoon', 'agave', 'agendaibiza', 'agnès', 'ahora', 'ai', 'aidasobetova', 'airports', 'akshardham', 'akshardhamtemple', 'alcoholic', 'alejado', 'alert', 'alla', 'allegation', 'altezze', 'amafresha', 'amazing', 'amigos', 'amore', 'amp', 'anahuac', 'anche', 'android', 'anello', 'animal', 'animals', 'anticipazioni', 'antiques', 'anáhuac', 'apart', 'aphuza', 'appelez', 'aprender', 'april', 'aquel', 'archidaily', 'architecturaldesign', 'architecturalproject', 'architecture', 
# ...

# %%
#comparing this documents words with bag of words of document B
k=0
bow_list_wordscommon = []
with open('bow.txt', 'r',encoding="utf-8") as file:
    for line in file:
        clear_line = line.replace('\n', '').replace(',', '').replace("'", '').strip()
        word = clear_line.split(' ')
        if word in vect1.get_feature_names() :
            bow_list_wordscommon.append(word)
            k=k+1
        
w = Counter(bow_list_wordscommon)
print(w,len(bow_list_wordscommon) )
# Out:
# Counter() 0
